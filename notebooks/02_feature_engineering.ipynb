# %% [markdown]
# # Feature Engineering - Fraud Detection System
#
# <!--
# Project: Fraud Detection System using ML
# Developer: Molla Samser (Founder) - https://rskworld.in
# Designer & Tester: Rima Khatun
# Email: help@rskworld.in, support@rskworld.in
# Phone: +91 93305 39277
# Location: Nutanhat, Mongolkote, Purba Burdwan, West Bengal, India, 713147
# Copyright © 2025 RSK World. All rights reserved.
# -->
#
# This notebook performs advanced feature engineering for fraud detection.

# %%
import sys
sys.path.append('..')

import pandas as pd
import numpy as np
from src.feature_engineering import FeatureEngineer
import warnings
warnings.filterwarnings('ignore')
